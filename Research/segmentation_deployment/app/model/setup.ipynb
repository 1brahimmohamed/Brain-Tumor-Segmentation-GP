# %%
# Install necessary dependencies for running the models
# !pip install monai

# %%
# !pip install pytorch_lightning==1.9.4

# %%
# !pip install --extra-index-url https://developer.download.nvidia.com/compute/redist --upgrade nvidia-dali-cuda110

# %%
import os

current_directory = os.getcwd()
root = os.path.dirname(os.path.dirname(current_directory))

# %%
# Navigate to the Apex directory
apex_dir = os.path.join(root , "app/apex")
os.chdir("/home/workstation04/GP_MMMAI/segmentation_deployment/app/apex")

# %%
#  Install Ninja build tool to accelerate building Apex --- in terminal
# !apt-get install ninja-build

# %% [markdown]
# #### make sure that The CUDA version matches the version that was used to compile PyTorch.
# must have nvcc

# %%
# !pip install -v --disable-pip-version-check --no-cache-dir --no-build-isolation --config-settings "--build-option=--cuda_ext" ./
# !pip install -v --disable-pip-version-check --no-cache-dir --no-build-isolation ./
# Out:
# Using pip 22.0.2 from /usr/lib/python3/dist-packages/pip (python 3.10)
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/workstation04/GP_MMMAI/Notebooks/NVIDIA_nnUNet/apex
#   Preparing metadata (pyproject.toml) ...   Running command Preparing metadata (pyproject.toml)
#
#
#   torch.__version__  = 2.3.1+cu121
#
#
#   running dist_info
#   creating /tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info
#   writing /tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/requires.txt
#   writing top-level names to /tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-modern-metadata-7hkzvyzn/apex.egg-info/SOURCES.txt'
# ...

# %%
# Install DLLogger
# !pip install 'git+https://github.com/NVIDIA/dllogger'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Cloning https://github.com/NVIDIA/dllogger to /tmp/pip-req-build-cjhpqzi1
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/dllogger /tmp/pip-req-build-cjhpqzi1
#   Resolved https://github.com/NVIDIA/dllogger to commit 0540a43971f4a8a16693a9de9de73c1072020769
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for DLLogger: filename=DLLogger-1.0.0-py3-none-any.whl size=5670 sha256=d2c6292be9c1dc623ab807b83ceb107c517fce769ffd908fd1384ea1882efac8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ox6rym4x/wheels/41/52/02/4093763d9dcfd96d85b3d90dec4afdcf40b3934c0d41cd1f3c
# Successfully built DLLogger
# ...

# %%
# Install or update the Rich library
# !pip install -U rich
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Navigate to the Apex directory
import os
os.chdir("/home/workstation04/GP_MMMAI/segmentation_deployment/app/apex")
os. getcwd()

# %%
os.chdir(root)
